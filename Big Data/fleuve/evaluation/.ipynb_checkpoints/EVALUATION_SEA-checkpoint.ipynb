# %% [markdown]
# # Sea data source - evaluation

# %%
import sys
sys.path.insert(1, '/home/patryk_mscwrona/repos') # inserting a library's directory

from pyspark.sql import SparkSession
from pyspark.context import SparkContext
from pyspark.sql.functions import *
from pyspark.sql.types import *
import numpy as np
import matplotlib.pyplot as plt

from river import optim
from river import linear_model
from river import forest
from river import tree
from river import ensemble
from river import preprocessing
from river import metrics
from river import dummy
from river import utils
from river import drift
import datetime as dt

import matplotlib.pyplot as plt
import matplotlib.pylab as pylab
params = {'legend.fontsize': 'medium',
          'figure.figsize': (18, 18),
         'axes.labelsize': 'x-large',
         'axes.titlesize':'x-large',
         'xtick.labelsize':'large',
         'ytick.labelsize':'large'}
pylab.rcParams.update(params)

from Fleuve.master import stream_miner_master
from Fleuve.master import evaluator_master
from Fleuve.master import predictor_master
from Fleuve.master import drift_detector_master

# initialize credit card input
from Fleuve.evaluation.initialize_scripts.initialize_electricity import InitializeE
from Fleuve.evaluation.initialize_scripts.initialize_sea import InitializeS

# %% [markdown]
# # SM1 - Sea

# %%
init = InitializeS() # loading a s
spark, input_schema, sc, sdf = init.spark, init.input_schema, init.sc, init.sdf
# Out:
# 23/08/20 21:21:28 WARN SparkSession: Using an existing Spark session; only runtime SQL configurations will take effect.

# %%
#SET TASK
task = {"cluster-9e14-w-0": {"models": [dummy.NoChangeClassifier(), 
                                        tree.ExtremelyFastDecisionTreeClassifier(max_depth=20 ), 
                                        forest.ARFClassifier(seed = 44, n_models = 5, max_depth = 20), 
                                        tree.HoeffdingTreeClassifier(max_depth = 20)] , 
                             "min_update_freq_s" : 60, 
                             "min_training_instances": 95000}, 
        "cluster-9e14-w-1" : {"models": [dummy.NoChangeClassifier(), 
                                        tree.ExtremelyFastDecisionTreeClassifier(max_depth=20 ), 
                                        forest.ARFClassifier(seed = 44, n_models = 5, max_depth = 20), 
                                        tree.HoeffdingTreeClassifier(max_depth = 20)] , 
                             "min_update_freq_s" : 60, 
                             "min_training_instances": 95000 }, 
        'workers': ["cluster-9e14-w-0", "cluster-9e14-w-1"],
       'eval_metrics': [utils.Rolling(metrics.Accuracy(), 10000), 
                        utils.Rolling(metrics.BalancedAccuracy(), 10000), 
                        utils.Rolling(metrics.F1(), 10000), 
                        utils.Rolling(metrics.CohenKappa(), 10000), 
                        utils.TimeRolling(metrics.Accuracy(), period=dt.timedelta(seconds = 20)), 
                        utils.TimeRolling(metrics.BalancedAccuracy(), period=dt.timedelta(seconds = 20)), 
                        utils.TimeRolling(metrics.F1(), period=dt.timedelta(seconds = 20)), 
                       utils.TimeRolling(metrics.CohenKappa(), period=dt.timedelta(seconds = 20))]}

data_cols = [field.name for field in input_schema.fields][:-1]
print(data_cols)
# data_cols = ['V' + str(i) for i in range(1,29)]
# data_cols.append('Amount') 

sm = stream_miner_master.StreamMinerMaster(data_cols, task)
output_schema = sm.output_schema

output_schema
# Out:
# ['V1', 'V2', 'V3']
# StructType([StructField('training_time', FloatType(), False), StructField('n', IntegerType(), False), StructField('hostname', StringType(), False), StructField('hash', StringType(), False), StructField('model_name', StringType(), False), StructField('prediction', DoubleType(), False), StructField('R_Accuracy', FloatType(), False), StructField('R_BalancedAccuracy', FloatType(), False), StructField('R_F1', FloatType(), False), StructField('R_CohenKappa', FloatType(), False), StructField('TR_Accuracy', FloatType(), False), StructField('TR_BalancedAccuracy', FloatType(), False), StructField('TR_F1', FloatType(), False), StructField('TR_CohenKappa', FloatType(), False), StructField('model_name_2', StringType(), False), StructField('prediction_2', DoubleType(), False), StructField('R_Accuracy_2', FloatType(), False), StructField('R_BalancedAccuracy_2', FloatType(), False), StructField('R_F1_2', FloatType(), False), StructField('R_CohenKappa_2', FloatType(), False), StructField('TR_Accuracy_2', FloatType(), False), StructField('TR_BalancedAccuracy_2', FloatType(), False), StructField('TR_F1_2', FloatType(), False), StructField('TR_CohenKappa_2', FloatType(), False), StructField('model_name_3', StringType(), False), StructField('prediction_3', DoubleType(), False), StructField('R_Accuracy_3', FloatType(), False), StructField('R_BalancedAccuracy_3', FloatType(), False), StructField('R_F1_3', FloatType(), False), StructField('R_CohenKappa_3', FloatType(), False), StructField('TR_Accuracy_3', FloatType(), False), StructField('TR_BalancedAccuracy_3', FloatType(), False), StructField('TR_F1_3', FloatType(), False), StructField('TR_CohenKappa_3', FloatType(), False), StructField('model_name_4', StringType(), False), StructField('prediction_4', DoubleType(), False), StructField('R_Accuracy_4', FloatType(), False), StructField('R_BalancedAccuracy_4', FloatType(), False), StructField('R_F1_4', FloatType(), False), StructField('R_CohenKappa_4', FloatType(), False), StructField('TR_Accuracy_4', FloatType(), False), StructField('TR_BalancedAccuracy_4', FloatType(), False), StructField('TR_F1_4', FloatType(), False), StructField('TR_CohenKappa_4', FloatType(), False)])

# %%
sm.transform_and_collect(sdf, "/user/hdfs/evaluation/sm/s1", "/user/hdfs/evaluation/sm/s1/chk")
# Out:
# 23/08/20 19:09:05 WARN package: Truncated the string representation of a plan since it was too large. This behavior can be adjusted by setting 'spark.sql.debug.maxToStringFields'.
# 23/08/20 19:09:06 WARN ResolveWriteToStream: spark.sql.adaptive.enabled is not supported in streaming DataFrames/Datasets and will be disabled.
# 23/08/20 19:09:24 WARN YarnScheduler: Initial job has not accepted any resources; check your cluster UI to ensure that workers are registered and have sufficient resources
# 23/08/20 19:09:39 WARN YarnScheduler: Initial job has not accepted any resources; check your cluster UI to ensure that workers are registered and have sufficient resources
# 23/08/20 19:10:14 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 68214 milliseconds
# 23/08/20 19:11:44 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 89844 milliseconds
# 23/08/20 19:13:53 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 129301 milliseconds
# 23/08/20 19:17:19 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 205867 milliseconds
# 23/08/20 19:21:35 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 255730 milliseconds
# ERROR:root:KeyboardInterrupt while sending command.
# Traceback (most recent call last):
#   File "/usr/lib/spark/python/lib/py4j-0.10.9.5-src.zip/py4j/java_gateway.py", line 1038, in send_command
#     response = connection.send_command(command)
#   File "/usr/lib/spark/python/lib/py4j-0.10.9.5-src.zip/py4j/clientserver.py", line 511, in send_command
#     answer = smart_decode(self.stream.readline()[:-1])
#   File "/opt/conda/miniconda3/lib/python3.10/socket.py", line 705, in readinto
#     return self._sock.recv_into(b)
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_100999/71273362.py in <cell line: 1>()
# ----> 1 sm.transform_and_collect(sdf, "/user/hdfs/evaluation/sm/s1", "/user/hdfs/evaluation/sm/s1/chk")
#
# /home/patryk_mscwrona/repos/Fleuve/master/stream_miner_master.py in transform_and_collect(self, sdf, OUTPUT_HDFS_PATH, OUTPUT_HDFS_CHECKPOINT_PATH)
#     136             .start()
#     137
# --> 138         query.awaitTermination()
#     139
#     140
#
# /usr/lib/spark/python/pyspark/sql/streaming.py in awaitTermination(self, timeout)
#     105             return self._jsq.awaitTermination(int(timeout * 1000))
#     106         else:
# --> 107             return self._jsq.awaitTermination()
#     108
#     109     @property  # type: ignore[misc]
#
# /usr/lib/spark/python/lib/py4j-0.10.9.5-src.zip/py4j/java_gateway.py in __call__(self, *args)
#    1318             proto.END_COMMAND_PART
#    1319
# -> 1320         answer = self.gateway_client.send_command(command)
#    1321         return_value = get_return_value(
#    1322             answer, self.gateway_client, self.target_id, self.name)
#
# /usr/lib/spark/python/lib/py4j-0.10.9.5-src.zip/py4j/java_gateway.py in send_command(self, command, retry, binary)
#    1036         connection = self._get_connection()
#    1037         try:
# -> 1038             response = connection.send_command(command)
#    1039             if binary:
#    1040                 return response, self._create_connection_guard(connection)
#
# /usr/lib/spark/python/lib/py4j-0.10.9.5-src.zip/py4j/clientserver.py in send_command(self, command)
#     509         try:
#     510             while True:
# --> 511                 answer = smart_decode(self.stream.readline()[:-1])
#     512                 logger.debug("Answer received: {0}".format(answer))
#     513                 # Happens when a the other end is dead. There might be an empty
#
# /opt/conda/miniconda3/lib/python3.10/socket.py in readinto(self, b)
#     703         while True:
#     704             try:
# --> 705                 return self._sock.recv_into(b)
#     706             except timeout:
#     707                 self._timeout_occurred = True
#
# KeyboardInterrupt:

# %%
df = spark.read.format("csv").options(header='false').schema(output_schema). \
load("hdfs://cluster-9e14-m/user/hdfs/evaluation/sm/s1")
pdf = df.toPandas()
pdf = pdf.sort_values(by=['n'])

print(pdf.shape)
print(np.max(pdf.training_time)) # seconds of training

# print(np.max(pdf.training_time)) # seconds of training

# pdf = pdf[pdf["hash"] == "dmtxlnz2aju84ypn"]
# Out:
# (200000, 44)
# 652.71014

# %%
print(np.max(pdf.n)) # seconds of training
np.unique(pdf.hash, return_counts=True)


# NoChangeClassifier_cluster-9e14-w-0_109272.pkl
# Out:
# 160000
# (array(['g71ome08g29h8b0j', 'v28uycdc763obojr'], dtype=object),
#  array([ 40000, 160000]))

# %%
pdf = pdf[pdf["hash"] == 'v28uycdc763obojr']

# %%
pdf
# Out:
#         training_time       n          hostname              hash  \
# 192500       0.002898       1  cluster-9e14-w-1  v28uycdc763obojr
# 192501       0.004355       2  cluster-9e14-w-1  v28uycdc763obojr
# 192502       0.005147       3  cluster-9e14-w-1  v28uycdc763obojr
# 192503       0.005908       4  cluster-9e14-w-1  v28uycdc763obojr
# 192504       0.007582       5  cluster-9e14-w-1  v28uycdc763obojr
# ...               ...     ...               ...               ...
# 42495      652.685791  159996  cluster-9e14-w-1  v28uycdc763obojr
# 42496      652.691650  159997  cluster-9e14-w-1  v28uycdc763obojr
# 42497      652.698364  159998  cluster-9e14-w-1  v28uycdc763obojr
# 42498      652.704407  159999  cluster-9e14-w-1  v28uycdc763obojr
# 42499      652.710144  160000  cluster-9e14-w-1  v28uycdc763obojr
#
#                 model_name  prediction  R_Accuracy  R_BalancedAccuracy  \
# 192500  NoChangeClassifier         0.0    0.000000            0.000000
# 192501  NoChangeClassifier         1.0    0.000000            0.000000
# 192502  NoChangeClassifier         0.0    0.333333            0.166667
# 192503  NoChangeClassifier         0.0    0.250000            0.166667
# 192504  NoChangeClassifier         1.0    0.200000            0.111111
# ...                    ...         ...         ...                 ...
# 42495   NoChangeClassifier         1.0    0.555200            0.495421
# 42496   NoChangeClassifier         1.0    0.555200            0.495421
# 42497   NoChangeClassifier         1.0    0.555300            0.495494
# 42498   NoChangeClassifier         1.0    0.555400            0.495569
# 42499   NoChangeClassifier         1.0    0.555300            0.495495
#
#             R_F1  R_CohenKappa  ...             model_name_4  prediction_4  \
# 192500  0.000000      0.000000  ...  HoeffdingTreeClassifier           0.0
# 192501  0.000000     -0.333333  ...  HoeffdingTreeClassifier           1.0
# 192502  0.000000      0.000000  ...  HoeffdingTreeClassifier           0.0
# 192503  0.000000     -0.200000  ...  HoeffdingTreeClassifier           0.0
# 192504  0.000000     -0.333333  ...  HoeffdingTreeClassifier           1.0
# ...          ...           ...  ...                      ...           ...
# 42495   0.669097     -0.009159  ...  HoeffdingTreeClassifier           1.0
# 42496   0.669097     -0.009159  ...  HoeffdingTreeClassifier           1.0
# 42497   0.669196     -0.009011  ...  HoeffdingTreeClassifier           1.0
# 42498   0.669295     -0.008863  ...  HoeffdingTreeClassifier           1.0
# 42499   0.669196     -0.009011  ...  HoeffdingTreeClassifier           0.0
#
#         R_Accuracy_4  R_BalancedAccuracy_4    R_F1_4  R_CohenKappa_4  \
# 192500      0.000000              0.000000  0.000000        0.000000
# 192501      0.000000              0.000000  0.000000       -0.333333
# 192502      0.333333              0.166667  0.000000        0.000000
# 192503      0.250000              0.166667  0.000000       -0.200000
# 192504      0.200000              0.111111  0.000000       -0.333333
# ...              ...                   ...       ...             ...
# 42495       0.995300              0.994473  0.996505        0.989332
# 42496       0.995300              0.994473  0.996505        0.989332
# 42497       0.995300              0.994472  0.996505        0.989331
# 42498       0.995300              0.994472  0.996505        0.989331
# 42499       0.995300              0.994473  0.996505        0.989332
#
#         TR_Accuracy_4  TR_BalancedAccuracy_4   TR_F1_4  TR_CohenKappa_4
# 192500       0.000000               0.000000  0.000000         0.000000
# 192501       0.000000               0.000000  0.000000        -0.333333
# 192502       0.333333               0.166667  0.000000         0.000000
# 192503       0.250000               0.166667  0.000000        -0.200000
# 192504       0.200000               0.111111  0.000000        -0.333333
# ...               ...                    ...       ...              ...
# 42495        0.994976               0.993695  0.996274         0.988564
# 42496        0.994975               0.993694  0.996273         0.988557
# 42497        0.994972               0.993690  0.996271         0.988555
# 42498        0.994972               0.993682  0.996273         0.988545
# 42499        0.994970               0.993685  0.996270         0.988548
#
# [160000 rows x 44 columns]

# %%
fig, axs = plt.subplots(2, 2)


axs[0, 0].plot(pdf.n, pdf.R_Accuracy, marker='.', markersize = 1)
axs[0, 0].plot(pdf.n, pdf.R_Accuracy_2, marker='.', markersize = 1)
axs[0, 0].plot(pdf.n, pdf.R_Accuracy_3, marker='.', markersize = 1)
axs[0, 0].plot(pdf.n, pdf.R_Accuracy_4, marker='.', markersize = 1)
axs[0,0].legend( ['NoChangeClassifier','ExtremelyFastDecisionTreeClassifier', 'ARFClassifier', 'HoeffdingTreeClassifier'], loc = 'lower right')
axs[0, 0].set_title('Accuracy')

axs[0, 1].plot(pdf.n, pdf.R_BalancedAccuracy, marker='.', markersize = 1)
axs[0, 1].plot(pdf.n, pdf.R_BalancedAccuracy_2, marker='.', markersize = 1)
axs[0, 1].plot(pdf.n, pdf.R_BalancedAccuracy_3, marker='.', markersize = 1)
axs[0, 1].plot(pdf.n, pdf.R_BalancedAccuracy_4, marker='.', markersize = 1)
axs[0, 1].legend( ['NoChangeClassifier','ExtremelyFastDecisionTreeClassifier', 'ARFClassifier', 'HoeffdingTreeClassifier'], loc = 'lower right')
axs[0, 1].set_title('Balanced Accuracy')

axs[1, 0].plot(pdf.n, pdf.R_F1, marker='.', markersize = 1)
axs[1, 0].plot(pdf.n, pdf.R_F1_2, marker='.', markersize = 1)
axs[1, 0].plot(pdf.n, pdf.R_F1_3, marker='.', markersize = 1)
axs[1, 0].plot(pdf.n, pdf.R_F1_4, marker='.', markersize = 1)
axs[1, 0].legend( ['NoChangeClassifier','ExtremelyFastDecisionTreeClassifier', 'ARFClassifier', 'HoeffdingTreeClassifier'], loc = 'lower right')
axs[1, 0].set_title('F1 Score')

axs[1, 1].plot(pdf.n, pdf.R_CohenKappa, marker='.', markersize = 1)
axs[1, 1].plot(pdf.n, pdf.R_CohenKappa_2, marker='.', markersize = 1)
axs[1, 1].plot(pdf.n, pdf.R_CohenKappa_3, marker='.', markersize = 1)
axs[1, 1].plot(pdf.n, pdf.R_CohenKappa_4, marker='.', markersize = 1)
axs[1, 1].legend( ['NoChangeClassifier','ExtremelyFastDecisionTreeClassifier', 'ARFClassifier', 'HoeffdingTreeClassifier'], loc = 'lower right')
axs[1, 1].set_title('Cohen Kappa')


for ax in axs.flat:
    ax.set(xlabel='Number of training data instances', ylabel='Metric Value')
#     handles, labels = ax.get_legend_handles_labels()
#     fig.legend(handles, labels, loc='upper center')
# Hide x labels and tick labels for top plots and y ticks for right plots.
# for ax in axs.flat:
#     ax.label_outer()

# %%
fig, axs = plt.subplots(2, 2)


axs[0, 0].plot(pdf.n, pdf.TR_Accuracy, marker='.', markersize = 1)
axs[0, 0].plot(pdf.n, pdf.TR_Accuracy_2, marker='.', markersize = 1)
axs[0, 0].plot(pdf.n, pdf.TR_Accuracy_3, marker='.', markersize = 1)
axs[0, 0].plot(pdf.n, pdf.TR_Accuracy_4, marker='.', markersize = 1)
axs[0,0].legend( ['NoChangeClassifier','ExtremelyFastDecisionTreeClassifier', 'ARFClassifier', 'HoeffdingTreeClassifier'], loc = 'lower right')
axs[0, 0].set_title('Accuracy')

axs[0, 1].plot(pdf.n, pdf.TR_BalancedAccuracy, marker='.', markersize = 1)
axs[0, 1].plot(pdf.n, pdf.TR_BalancedAccuracy_2, marker='.', markersize = 1)
axs[0, 1].plot(pdf.n, pdf.TR_BalancedAccuracy_3, marker='.', markersize = 1)
axs[0, 1].plot(pdf.n, pdf.TR_BalancedAccuracy_4, marker='.', markersize = 1)
axs[0, 1].legend( ['NoChangeClassifier','ExtremelyFastDecisionTreeClassifier', 'ARFClassifier', 'HoeffdingTreeClassifier'], loc = 'lower right')
axs[0, 1].set_title('Balanced Accuracy')

axs[1, 0].plot(pdf.n, pdf.TR_F1, marker='.', markersize = 1)
axs[1, 0].plot(pdf.n, pdf.TR_F1_2, marker='.', markersize = 1)
axs[1, 0].plot(pdf.n, pdf.TR_F1_3, marker='.', markersize = 1)
axs[1, 0].plot(pdf.n, pdf.TR_F1_4, marker='.', markersize = 1)
axs[1, 0].legend( ['NoChangeClassifier','ExtremelyFastDecisionTreeClassifier', 'ARFClassifier', 'HoeffdingTreeClassifier'], loc = 'lower right')
axs[1, 0].set_title('F1 Score')

axs[1, 1].plot(pdf[pdf["R_CohenKappa"] >= -0.1].n, pdf[pdf["R_CohenKappa"] >= -0.1].TR_CohenKappa, marker='.', markersize = 1)
axs[1, 1].plot(pdf[pdf["R_CohenKappa_2"] >= -0.1].n, pdf[pdf["R_CohenKappa_2"] >= -0.1].TR_CohenKappa_2, marker='.', markersize = 1)
axs[1, 1].plot(pdf[pdf["R_CohenKappa_3"] >= -0.1].n, pdf[pdf["R_CohenKappa_3"] >= -0.1].TR_CohenKappa_3, marker='.', markersize = 1)
axs[1, 1].plot(pdf[pdf["R_CohenKappa_4"] >= -0.1].n, pdf[pdf["R_CohenKappa_4"] >= -0.1].TR_CohenKappa_4, marker='.', markersize = 1)
axs[1, 1].legend( ['NoChangeClassifier','ExtremelyFastDecisionTreeClassifier', 'ARFClassifier', 'HoeffdingTreeClassifier'], loc = 'lower right')
axs[1, 1].set_title('Cohen Kappa')

for ax in axs.flat:
    ax.set(xlabel='Number of training data instances', ylabel='Metric Value')

# Hide x labels and tick labels for top plots and y ticks for right plots.
# for ax in axs.flat:
#     ax.label_outer()

# %% [markdown]
# # SM2 - SEA

# %%
#SET TASK
task = {"cluster-9e14-w-0": {"pretrained_models": ["NoChangeClassifier_cluster-9e14-w-1_150921.pkl",
                                                   "ExtremelyFastDecisionTreeClassifier_cluster-9e14-w-1_150921.pkl",
                                                   "ARFClassifier_cluster-9e14-w-1_150921.pkl",
                                                   "HoeffdingTreeClassifier_cluster-9e14-w-1_150921.pkl"
                                                  ]},
        "cluster-9e14-w-1" : {"pretrained_models": ["NoChangeClassifier_cluster-9e14-w-1_150921.pkl",
                                                   "ExtremelyFastDecisionTreeClassifier_cluster-9e14-w-1_150921.pkl",
                                                   "ARFClassifier_cluster-9e14-w-1_150921.pkl",
                                                   "HoeffdingTreeClassifier_cluster-9e14-w-1_150921.pkl"]},
        'workers': ["cluster-9e14-w-0", "cluster-9e14-w-1"],
       'eval_metrics': [utils.Rolling(metrics.Accuracy(), 10000), 
                        utils.Rolling(metrics.BalancedAccuracy(), 10000), 
                        utils.Rolling(metrics.F1(), 10000), 
                        utils.Rolling(metrics.CohenKappa(), 10000)]}

data_cols = [field.name for field in input_schema.fields][:-1]
print(data_cols)
# data_cols = ['V' + str(i) for i in range(1,29)]
# data_cols.append('Amount') 

sm = stream_miner_master.StreamMinerMaster(data_cols, task)
output_schema = sm.output_schema

output_schema
# Out:
# ['V1', 'V2', 'V3']
# StructType([StructField('training_time', FloatType(), False), StructField('n', IntegerType(), False), StructField('hostname', StringType(), False), StructField('hash', StringType(), False), StructField('model_name', StringType(), False), StructField('prediction', DoubleType(), False), StructField('R_Accuracy', FloatType(), False), StructField('R_BalancedAccuracy', FloatType(), False), StructField('R_F1', FloatType(), False), StructField('R_CohenKappa', FloatType(), False), StructField('model_name_2', StringType(), False), StructField('prediction_2', DoubleType(), False), StructField('R_Accuracy_2', FloatType(), False), StructField('R_BalancedAccuracy_2', FloatType(), False), StructField('R_F1_2', FloatType(), False), StructField('R_CohenKappa_2', FloatType(), False), StructField('model_name_3', StringType(), False), StructField('prediction_3', DoubleType(), False), StructField('R_Accuracy_3', FloatType(), False), StructField('R_BalancedAccuracy_3', FloatType(), False), StructField('R_F1_3', FloatType(), False), StructField('R_CohenKappa_3', FloatType(), False), StructField('model_name_4', StringType(), False), StructField('prediction_4', DoubleType(), False), StructField('R_Accuracy_4', FloatType(), False), StructField('R_BalancedAccuracy_4', FloatType(), False), StructField('R_F1_4', FloatType(), False), StructField('R_CohenKappa_4', FloatType(), False)])

# %%
sm.transform_and_collect(sdf, "/user/hdfs/evaluation/sm/s2", "/user/hdfs/evaluation/sm/s2/chk")
# Out:
# 23/08/20 19:54:07 WARN package: Truncated the string representation of a plan since it was too large. This behavior can be adjusted by setting 'spark.sql.debug.maxToStringFields'.
# 23/08/20 19:54:07 WARN ResolveWriteToStream: spark.sql.adaptive.enabled is not supported in streaming DataFrames/Datasets and will be disabled.
# 23/08/20 19:54:38 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 30327 milliseconds
# 23/08/20 19:54:52 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 14080 milliseconds
# 23/08/20 19:55:20 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 28322 milliseconds
# 23/08/20 19:55:30 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 10001 milliseconds
# ERROR:root:KeyboardInterrupt while sending command.
# Traceback (most recent call last):
#   File "/usr/lib/spark/python/lib/py4j-0.10.9.5-src.zip/py4j/java_gateway.py", line 1038, in send_command
#     response = connection.send_command(command)
#   File "/usr/lib/spark/python/lib/py4j-0.10.9.5-src.zip/py4j/clientserver.py", line 511, in send_command
#     answer = smart_decode(self.stream.readline()[:-1])
#   File "/opt/conda/miniconda3/lib/python3.10/socket.py", line 705, in readinto
#     return self._sock.recv_into(b)
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_114364/3425995927.py in <cell line: 1>()
# ----> 1 sm.transform_and_collect(sdf, "/user/hdfs/evaluation/sm/s2", "/user/hdfs/evaluation/sm/s2/chk")
#
# /home/patryk_mscwrona/repos/Fleuve/master/stream_miner_master.py in transform_and_collect(self, sdf, OUTPUT_HDFS_PATH, OUTPUT_HDFS_CHECKPOINT_PATH)
#     136             .start()
#     137
# --> 138         query.awaitTermination()
#     139
#     140
#
# /usr/lib/spark/python/pyspark/sql/streaming.py in awaitTermination(self, timeout)
#     105             return self._jsq.awaitTermination(int(timeout * 1000))
#     106         else:
# --> 107             return self._jsq.awaitTermination()
#     108
#     109     @property  # type: ignore[misc]
#
# /usr/lib/spark/python/lib/py4j-0.10.9.5-src.zip/py4j/java_gateway.py in __call__(self, *args)
#    1318             proto.END_COMMAND_PART
#    1319
# -> 1320         answer = self.gateway_client.send_command(command)
#    1321         return_value = get_return_value(
#    1322             answer, self.gateway_client, self.target_id, self.name)
#
# /usr/lib/spark/python/lib/py4j-0.10.9.5-src.zip/py4j/java_gateway.py in send_command(self, command, retry, binary)
#    1036         connection = self._get_connection()
#    1037         try:
# -> 1038             response = connection.send_command(command)
#    1039             if binary:
#    1040                 return response, self._create_connection_guard(connection)
#
# /usr/lib/spark/python/lib/py4j-0.10.9.5-src.zip/py4j/clientserver.py in send_command(self, command)
#     509         try:
#     510             while True:
# --> 511                 answer = smart_decode(self.stream.readline()[:-1])
#     512                 logger.debug("Answer received: {0}".format(answer))
#     513                 # Happens when a the other end is dead. There might be an empty
#
# /opt/conda/miniconda3/lib/python3.10/socket.py in readinto(self, b)
#     703         while True:
#     704             try:
# --> 705                 return self._sock.recv_into(b)
#     706             except timeout:
#     707                 self._timeout_occurred = True
#
# KeyboardInterrupt:

# %%
df = spark.read.format("csv").options(header='false').schema(output_schema). \
load("hdfs://cluster-9e14-m/user/hdfs/evaluation/sm/s2")
pdf = df.toPandas()
pdf = pdf.sort_values(by=['n'])

print(pdf.shape)
print(np.max(pdf.training_time)) # seconds of training

print(np.max(pdf.n)) # seconds of training
np.unique(pdf.hash, return_counts=True)
# Out:
# (200000, 28)
# 488.58215
# 102500
# (array(['7krtudm5dg0qogu6', 'v6h8emhbi3rhirqo'], dtype=object),
#  array([102500,  97500]))

# %%
pdf = pdf[pdf["hash"] == "7krtudm5dg0qogu6"]

# NoChangeClassifier_cluster-9e14-w-0_109272.pkl

# %%
fig, axs = plt.subplots(2, 2)


axs[0, 0].plot(pdf.n, pdf.R_Accuracy, marker='.', markersize = 1)
axs[0, 0].plot(pdf.n, pdf.R_Accuracy_2, marker='.', markersize = 1)
axs[0, 0].plot(pdf.n, pdf.R_Accuracy_3, marker='.', markersize = 1)
axs[0, 0].plot(pdf.n, pdf.R_Accuracy_4, marker='.', markersize = 1)
axs[0,0].legend( ['NoChangeClassifier','ExtremelyFastDecisionTreeClassifier', 'ARFClassifier', 'HoeffdingTreeClassifier'], loc = 'lower right')
axs[0, 0].set_title('Accuracy')

axs[0, 1].plot(pdf.n, pdf.R_BalancedAccuracy, marker='.', markersize = 1)
axs[0, 1].plot(pdf.n, pdf.R_BalancedAccuracy_2, marker='.', markersize = 1)
axs[0, 1].plot(pdf.n, pdf.R_BalancedAccuracy_3, marker='.', markersize = 1)
axs[0, 1].plot(pdf.n, pdf.R_BalancedAccuracy_4, marker='.', markersize = 1)
axs[0, 1].legend( ['NoChangeClassifier','ExtremelyFastDecisionTreeClassifier', 'ARFClassifier', 'HoeffdingTreeClassifier'], loc = 'lower right')
axs[0, 1].set_title('Balanced Accuracy')

axs[1, 0].plot(pdf.n, pdf.R_F1, marker='.', markersize = 1)
axs[1, 0].plot(pdf.n, pdf.R_F1_2, marker='.', markersize = 1)
axs[1, 0].plot(pdf.n, pdf.R_F1_3, marker='.', markersize = 1)
axs[1, 0].plot(pdf.n, pdf.R_F1_4, marker='.', markersize = 1)
axs[1, 0].legend( ['NoChangeClassifier','ExtremelyFastDecisionTreeClassifier', 'ARFClassifier', 'HoeffdingTreeClassifier'], loc = 'lower right')
axs[1, 0].set_title('F1 Score')

axs[1, 1].plot(pdf[pdf["R_CohenKappa"] >= -0.1].n, pdf[pdf["R_CohenKappa"] >= -0.1].R_CohenKappa, marker='.', markersize = 1)
axs[1, 1].plot(pdf[pdf["R_CohenKappa_2"] >= -0.1].n, pdf[pdf["R_CohenKappa_2"] >= -0.1].R_CohenKappa_2, marker='.', markersize = 1)
axs[1, 1].plot(pdf[pdf["R_CohenKappa_3"] >= -0.1].n, pdf[pdf["R_CohenKappa_3"] >= -0.1].R_CohenKappa_3, marker='.', markersize = 1)
axs[1, 1].plot(pdf[pdf["R_CohenKappa_4"] >= -0.1].n, pdf[pdf["R_CohenKappa_4"] >= -0.1].R_CohenKappa_4, marker='.', markersize = 1)
axs[1, 1].legend( ['NoChangeClassifier','ExtremelyFastDecisionTreeClassifier', 'ARFClassifier', 'HoeffdingTreeClassifier'], loc = 'center right')
axs[1, 1].set_title('Cohen Kappa')


for ax in axs.flat:
    ax.set(xlabel='Number of training data instances', ylabel='Metric Value')
#     handles, labels = ax.get_legend_handles_labels()
#     fig.legend(handles, labels, loc='upper center')
# Hide x labels and tick labels for top plots and y ticks for right plots.
# for ax in axs.flat:
#     ax.label_outer()

# %% [markdown]
# # Sea 3 - evaluator

# %%
#SET TASK
task = {"cluster-9e14-w-0": {"pretrained_models": ["NoChangeClassifier_cluster-9e14-w-1_150921.pkl",
                                                   "ExtremelyFastDecisionTreeClassifier_cluster-9e14-w-1_150921.pkl",
                                                   "ARFClassifier_cluster-9e14-w-1_150921.pkl",
                                                   "HoeffdingTreeClassifier_cluster-9e14-w-1_150921.pkl"
                                                  ]},
        "cluster-9e14-w-1" : {"pretrained_models": ["NoChangeClassifier_cluster-9e14-w-1_150921.pkl",
                                                   "ExtremelyFastDecisionTreeClassifier_cluster-9e14-w-1_150921.pkl",
                                                   "ARFClassifier_cluster-9e14-w-1_150921.pkl",
                                                   "HoeffdingTreeClassifier_cluster-9e14-w-1_150921.pkl"]},
        'workers': ["cluster-9e14-w-0", "cluster-9e14-w-1"],
       'eval_metrics': [utils.Rolling(metrics.Accuracy(), 10000), 
                        utils.Rolling(metrics.BalancedAccuracy(), 10000), 
                        utils.Rolling(metrics.F1(), 10000), 
                        utils.Rolling(metrics.CohenKappa(), 10000),
                       metrics.Accuracy(),
                       metrics.BalancedAccuracy(),
                       metrics.F1(),
                       metrics.CohenKappa()]}

# %%
sm = evaluator_master.EvaluatorMaster(data_cols, task)
output_schema = sm.output_schema

output_schema
# Out:
# StructType([StructField('training_time', FloatType(), False), StructField('n', IntegerType(), False), StructField('hostname', StringType(), False), StructField('hash', StringType(), False), StructField('model_name', StringType(), False), StructField('prediction', DoubleType(), False), StructField('R_Accuracy', FloatType(), False), StructField('R_BalancedAccuracy', FloatType(), False), StructField('R_F1', FloatType(), False), StructField('R_CohenKappa', FloatType(), False), StructField('Accuracy', FloatType(), False), StructField('BalancedAccuracy', FloatType(), False), StructField('F1', FloatType(), False), StructField('CohenKappa', FloatType(), False), StructField('model_name_2', StringType(), False), StructField('prediction_2', DoubleType(), False), StructField('R_Accuracy_2', FloatType(), False), StructField('R_BalancedAccuracy_2', FloatType(), False), StructField('R_F1_2', FloatType(), False), StructField('R_CohenKappa_2', FloatType(), False), StructField('Accuracy_2', FloatType(), False), StructField('BalancedAccuracy_2', FloatType(), False), StructField('F1_2', FloatType(), False), StructField('CohenKappa_2', FloatType(), False), StructField('model_name_3', StringType(), False), StructField('prediction_3', DoubleType(), False), StructField('R_Accuracy_3', FloatType(), False), StructField('R_BalancedAccuracy_3', FloatType(), False), StructField('R_F1_3', FloatType(), False), StructField('R_CohenKappa_3', FloatType(), False), StructField('Accuracy_3', FloatType(), False), StructField('BalancedAccuracy_3', FloatType(), False), StructField('F1_3', FloatType(), False), StructField('CohenKappa_3', FloatType(), False), StructField('model_name_4', StringType(), False), StructField('prediction_4', DoubleType(), False), StructField('R_Accuracy_4', FloatType(), False), StructField('R_BalancedAccuracy_4', FloatType(), False), StructField('R_F1_4', FloatType(), False), StructField('R_CohenKappa_4', FloatType(), False), StructField('Accuracy_4', FloatType(), False), StructField('BalancedAccuracy_4', FloatType(), False), StructField('F1_4', FloatType(), False), StructField('CohenKappa_4', FloatType(), False)])

# %%
sm.transform_and_collect(sdf, "/user/hdfs/evaluation/sm/s3", "/user/hdfs/evaluation/sm/s3/chk")
# Out:
# 23/08/20 19:26:01 WARN ResolveWriteToStream: spark.sql.adaptive.enabled is not supported in streaming DataFrames/Datasets and will be disabled.
# 23/08/20 19:28:17 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 135201 milliseconds
# ERROR:root:KeyboardInterrupt while sending command.
# Traceback (most recent call last):
#   File "/usr/lib/spark/python/lib/py4j-0.10.9.5-src.zip/py4j/java_gateway.py", line 1038, in send_command
#     response = connection.send_command(command)
#   File "/usr/lib/spark/python/lib/py4j-0.10.9.5-src.zip/py4j/clientserver.py", line 511, in send_command
#     answer = smart_decode(self.stream.readline()[:-1])
#   File "/opt/conda/miniconda3/lib/python3.10/socket.py", line 705, in readinto
#     return self._sock.recv_into(b)
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_100999/4119594100.py in <cell line: 1>()
# ----> 1 sm.transform_and_collect(sdf, "/user/hdfs/evaluation/sm/s3", "/user/hdfs/evaluation/sm/s3/chk")
#
# /home/patryk_mscwrona/repos/Fleuve/master/evaluator_master.py in transform_and_collect(self, sdf, OUTPUT_HDFS_PATH, OUTPUT_HDFS_CHECKPOINT_PATH)
#     121             .start()
#     122
# --> 123         query.awaitTermination()
#     124
#     125
#
# /usr/lib/spark/python/pyspark/sql/streaming.py in awaitTermination(self, timeout)
#     105             return self._jsq.awaitTermination(int(timeout * 1000))
#     106         else:
# --> 107             return self._jsq.awaitTermination()
#     108
#     109     @property  # type: ignore[misc]
#
# /usr/lib/spark/python/lib/py4j-0.10.9.5-src.zip/py4j/java_gateway.py in __call__(self, *args)
#    1318             proto.END_COMMAND_PART
#    1319
# -> 1320         answer = self.gateway_client.send_command(command)
#    1321         return_value = get_return_value(
#    1322             answer, self.gateway_client, self.target_id, self.name)
#
# /usr/lib/spark/python/lib/py4j-0.10.9.5-src.zip/py4j/java_gateway.py in send_command(self, command, retry, binary)
#    1036         connection = self._get_connection()
#    1037         try:
# -> 1038             response = connection.send_command(command)
#    1039             if binary:
#    1040                 return response, self._create_connection_guard(connection)
#
# /usr/lib/spark/python/lib/py4j-0.10.9.5-src.zip/py4j/clientserver.py in send_command(self, command)
#     509         try:
#     510             while True:
# --> 511                 answer = smart_decode(self.stream.readline()[:-1])
#     512                 logger.debug("Answer received: {0}".format(answer))
#     513                 # Happens when a the other end is dead. There might be an empty
#
# /opt/conda/miniconda3/lib/python3.10/socket.py in readinto(self, b)
#     703         while True:
#     704             try:
# --> 705                 return self._sock.recv_into(b)
#     706             except timeout:
#     707                 self._timeout_occurred = True
#
# KeyboardInterrupt:

# %%
df = spark.read.format("csv").options(header='false').schema(output_schema). \
load("hdfs://cluster-9e14-m/user/hdfs/evaluation/sm/s3")
pdf = df.toPandas()
pdf = pdf.sort_values(by=['n'])

print(pdf.shape)
print(np.max(pdf.training_time)) # seconds of training

print(np.max(pdf.n)) # seconds of training
np.unique(pdf.hash, return_counts=True)
# Out:
# 23/08/20 21:21:41 WARN package: Truncated the string representation of a plan since it was too large. This behavior can be adjusted by setting 'spark.sql.debug.maxToStringFields'.
# (202500, 44)
# 97.31352
# 122500
# (array(['8h3zqb75ch6b02x0', '8va1v78lkikkof9c', 'nypk5pgv8dnf2o09'],
#        dtype=object),
#  array([  2500,  77500, 122500]))

# %%
pdf = pdf[pdf["hash"] == "nypk5pgv8dnf2o09"]

# %%
fig, axs = plt.subplots(2, 2)


axs[0, 0].plot(pdf.n, pdf.R_Accuracy, marker='.', markersize = 1)
axs[0, 0].plot(pdf.n, pdf.R_Accuracy_2, marker='.', markersize = 1)
axs[0, 0].plot(pdf.n, pdf.R_Accuracy_3, marker='.', markersize = 1)
axs[0, 0].plot(pdf.n, pdf.R_Accuracy_4, marker='.', markersize = 1)
axs[0,0].legend( ['NoChangeClassifier','ExtremelyFastDecisionTreeClassifier', 'ARFClassifier', 'HoeffdingTreeClassifier'], loc = 'lower right')
axs[0, 0].set_title('Accuracy')

axs[0, 1].plot(pdf.n, pdf.R_BalancedAccuracy, marker='.', markersize = 1)
axs[0, 1].plot(pdf.n, pdf.R_BalancedAccuracy_2, marker='.', markersize = 1)
axs[0, 1].plot(pdf.n, pdf.R_BalancedAccuracy_3, marker='.', markersize = 1)
axs[0, 1].plot(pdf.n, pdf.R_BalancedAccuracy_4, marker='.', markersize = 1)
axs[0, 1].legend( ['NoChangeClassifier','ExtremelyFastDecisionTreeClassifier', 'ARFClassifier', 'HoeffdingTreeClassifier'], loc = 'lower right')
axs[0, 1].set_title('Balanced Accuracy')

axs[1, 0].plot(pdf.n, pdf.R_F1, marker='.', markersize = 1)
axs[1, 0].plot(pdf.n, pdf.R_F1_2, marker='.', markersize = 1)
axs[1, 0].plot(pdf.n, pdf.R_F1_3, marker='.', markersize = 1)
axs[1, 0].plot(pdf.n, pdf.R_F1_4, marker='.', markersize = 1)
axs[1, 0].legend( ['NoChangeClassifier','ExtremelyFastDecisionTreeClassifier', 'ARFClassifier', 'HoeffdingTreeClassifier'], loc = 'lower right')
axs[1, 0].set_title('F1 Score')

axs[1, 1].plot(pdf[pdf["R_CohenKappa"] >= -0.2].n, pdf[pdf["R_CohenKappa"] >= -0.2].R_CohenKappa, marker='.', markersize = 1)
axs[1, 1].plot(pdf[pdf["R_CohenKappa_2"] >= -0.2].n, pdf[pdf["R_CohenKappa_2"] >= -0.2].R_CohenKappa_2, marker='.', markersize = 1)
axs[1, 1].plot(pdf[pdf["R_CohenKappa_3"] >= -0.2].n, pdf[pdf["R_CohenKappa_3"] >= -0.2].R_CohenKappa_3, marker='.', markersize = 1)
axs[1, 1].plot(pdf[pdf["R_CohenKappa_4"] >= -0.2].n, pdf[pdf["R_CohenKappa_4"] >= -0.2].R_CohenKappa_4, marker='.', markersize = 1)
axs[1, 1].legend( ['NoChangeClassifier','ExtremelyFastDecisionTreeClassifier', 'ARFClassifier', 'HoeffdingTreeClassifier'], loc = 'center right')
axs[1, 1].set_title('Cohen Kappa')


for ax in axs.flat:
    ax.set(xlabel='Number of data instances', ylabel='Metric Value')
#     handles, labels = ax.get_legend_handles_labels()
#     fig.legend(handles, labels, loc='upper center')
# Hide x labels and tick labels for top plots and y ticks for right plots.
# for ax in axs.flat:
#     ax.label_outer()

# %% [markdown]
# ### Final metrics on the whole data source - Evaluator

# %%
pdf = pdf.reset_index(drop=True)

# %%
pdf.iloc[pdf.shape[0]-1,:]
# Out:
# training_time                                     97.313522
# n                                                    122500
# hostname                                   cluster-9e14-w-1
# hash                                       nypk5pgv8dnf2o09
# model_name                               NoChangeClassifier
# prediction                                              1.0
# R_Accuracy                                           0.6829
# R_BalancedAccuracy                                      0.5
# R_F1                                               0.811575
# R_CohenKappa                                            0.0
# Accuracy                                           0.682441
# BalancedAccuracy                                        0.5
# F1                                                 0.811251
# CohenKappa                                              0.0
# model_name_2            ExtremelyFastDecisionTreeClassifier
# prediction_2                                            0.0
# R_Accuracy_2                                         0.9942
# R_BalancedAccuracy_2                               0.993388
# R_F1_2                                             0.995753
# R_CohenKappa_2                                      0.98661
# Accuracy_2                                         0.995224
# BalancedAccuracy_2                                 0.994041
# F1_2                                               0.996504
# CohenKappa_2                                       0.988972
# model_name_3                                  ARFClassifier
# prediction_3                                            0.0
# R_Accuracy_3                                          0.996
# R_BalancedAccuracy_3                               0.994622
# R_F1_3                                             0.997075
# R_CohenKappa_3                                      0.99075
# Accuracy_3                                         0.997037
# BalancedAccuracy_3                                 0.996131
# F1_3                                               0.997831
# CohenKappa_3                                       0.993157
# model_name_4                        HoeffdingTreeClassifier
# prediction_4                                            0.0
# R_Accuracy_4                                         0.9955
# R_BalancedAccuracy_4                               0.994932
# R_F1_4                                             0.996705
# R_CohenKappa_4                                     0.989612
# Accuracy_4                                         0.995739
# BalancedAccuracy_4                                 0.995043
# F1_4                                               0.996878
# CohenKappa_4                                       0.990168
# Name: 122499, dtype: object

# %% [markdown]
# **NoChange:**
#
# Accuracy                                           0.682441
#
# BalancedAccuracy                                        0.5
#
# F1                                                 0.811251
#
# CohenKappa                                              0.0
#
# **EFTD:**
#
# Accuracy                                        0.995224
#
# BalancedAccuracy                                0.994041
#
# F1                                             0.996504
#
# CohenKappa                                      0.988972
#
# **ARF:**
#
# Accuracy                                        **0.997037**
#
# BalancedAccuracy                                **0.996131**
#
# F1                                             **0.997831**
#
# CohenKappa                                       **0.993157**
#
# **HT :**
#
# Accuracy                                         0.995739
#
# BalancedAccuracy                                 0.995043
#
# F1                                               0.996878
#
# CohenKappa                                       0.990168

# %% [markdown]
# # Sea 4 - Predictor

# %%
#SET TASK
task = {"cluster-9e14-w-0": {"pretrained_models": ["NoChangeClassifier_cluster-9e14-w-1_150921.pkl",
                                                   "ExtremelyFastDecisionTreeClassifier_cluster-9e14-w-1_150921.pkl",
                                                   "ARFClassifier_cluster-9e14-w-1_150921.pkl",
                                                   "HoeffdingTreeClassifier_cluster-9e14-w-1_150921.pkl"
                                                  ]},
        "cluster-9e14-w-1" : {"pretrained_models": ["NoChangeClassifier_cluster-9e14-w-1_150921.pkl",
                                                   "ExtremelyFastDecisionTreeClassifier_cluster-9e14-w-1_150921.pkl",
                                                   "ARFClassifier_cluster-9e14-w-1_150921.pkl",
                                                   "HoeffdingTreeClassifier_cluster-9e14-w-1_150921.pkl"]},
        'workers': ["cluster-9e14-w-0", "cluster-9e14-w-1"]}

data_cols = [field.name for field in input_schema.fields][:-1]
print(data_cols)
# data_cols = ['V' + str(i) for i in range(1,29)]
# data_cols.append('Amount') 

sm = stream_miner_master.StreamMinerMaster(data_cols, task)
output_schema = sm.output_schema

output_schema
# Out:
# ['V1', 'V2', 'V3']
# StructType([StructField('training_time', FloatType(), False), StructField('n', IntegerType(), False), StructField('hostname', StringType(), False), StructField('hash', StringType(), False), StructField('model_name', StringType(), False), StructField('prediction', DoubleType(), False), StructField('model_name_2', StringType(), False), StructField('prediction_2', DoubleType(), False), StructField('model_name_3', StringType(), False), StructField('prediction_3', DoubleType(), False), StructField('model_name_4', StringType(), False), StructField('prediction_4', DoubleType(), False)])

# %%
sm = predictor_master.PredictorMaster(data_cols, task)
output_schema = sm.output_schema

output_schema
# Out:
# StructType([StructField('training_time', FloatType(), False), StructField('n', IntegerType(), False), StructField('hostname', StringType(), False), StructField('hash', StringType(), False), StructField('model_name', StringType(), False), StructField('prediction', DoubleType(), False), StructField('model_name_2', StringType(), False), StructField('prediction_2', DoubleType(), False), StructField('model_name_3', StringType(), False), StructField('prediction_3', DoubleType(), False), StructField('model_name_4', StringType(), False), StructField('prediction_4', DoubleType(), False)])

# %%
sm.transform_and_collect(sdf, "/user/hdfs/evaluation/sm/s4", "/user/hdfs/evaluation/sm/s4/chk")
# Out:
# 23/08/20 19:40:16 WARN ResolveWriteToStream: spark.sql.adaptive.enabled is not supported in streaming DataFrames/Datasets and will be disabled.
# 23/08/20 19:41:36 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 80689 milliseconds
# ERROR:root:KeyboardInterrupt while sending command.
# Traceback (most recent call last):
#   File "/usr/lib/spark/python/lib/py4j-0.10.9.5-src.zip/py4j/java_gateway.py", line 1038, in send_command
#     response = connection.send_command(command)
#   File "/usr/lib/spark/python/lib/py4j-0.10.9.5-src.zip/py4j/clientserver.py", line 511, in send_command
#     answer = smart_decode(self.stream.readline()[:-1])
#   File "/opt/conda/miniconda3/lib/python3.10/socket.py", line 705, in readinto
#     return self._sock.recv_into(b)
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_100999/2135098406.py in <cell line: 1>()
# ----> 1 sm.transform_and_collect(sdf, "/user/hdfs/evaluation/sm/s4", "/user/hdfs/evaluation/sm/s4/chk")
#
# /home/patryk_mscwrona/repos/Fleuve/master/predictor_master.py in transform_and_collect(self, sdf, OUTPUT_HDFS_PATH, OUTPUT_HDFS_CHECKPOINT_PATH)
#      89             .start()
#      90
# ---> 91         query.awaitTermination()
#      92
#      93
#
# /usr/lib/spark/python/pyspark/sql/streaming.py in awaitTermination(self, timeout)
#     105             return self._jsq.awaitTermination(int(timeout * 1000))
#     106         else:
# --> 107             return self._jsq.awaitTermination()
#     108
#     109     @property  # type: ignore[misc]
#
# /usr/lib/spark/python/lib/py4j-0.10.9.5-src.zip/py4j/java_gateway.py in __call__(self, *args)
#    1318             proto.END_COMMAND_PART
#    1319
# -> 1320         answer = self.gateway_client.send_command(command)
#    1321         return_value = get_return_value(
#    1322             answer, self.gateway_client, self.target_id, self.name)
#
# /usr/lib/spark/python/lib/py4j-0.10.9.5-src.zip/py4j/java_gateway.py in send_command(self, command, retry, binary)
#    1036         connection = self._get_connection()
#    1037         try:
# -> 1038             response = connection.send_command(command)
#    1039             if binary:
#    1040                 return response, self._create_connection_guard(connection)
#
# /usr/lib/spark/python/lib/py4j-0.10.9.5-src.zip/py4j/clientserver.py in send_command(self, command)
#     509         try:
#     510             while True:
# --> 511                 answer = smart_decode(self.stream.readline()[:-1])
#     512                 logger.debug("Answer received: {0}".format(answer))
#     513                 # Happens when a the other end is dead. There might be an empty
#
# /opt/conda/miniconda3/lib/python3.10/socket.py in readinto(self, b)
#     703         while True:
#     704             try:
# --> 705                 return self._sock.recv_into(b)
#     706             except timeout:
#     707                 self._timeout_occurred = True
#
# KeyboardInterrupt:

# %%
df = spark.read.format("csv").options(header='false').schema(output_schema). \
load("hdfs://cluster-9e14-m/user/hdfs/evaluation/sm/s4")
pdf = df.toPandas()
pdf = pdf.sort_values(by=['n'])

print(pdf.shape)
print(np.max(pdf.training_time)) # seconds of training

print(np.max(pdf.n)) # seconds of training
np.unique(pdf.hash, return_counts=True)
# Out:
# (225000, 12)
# 42.25336
# 122500
# (array(['0xrgf01465dagg7w', '57vi7d1qn03zdxfy', 's0zsl3ktaqmuyica',
#         'v4y5fb9yd3h8hbaj'], dtype=object),
#  array([122500,   2500,  22500,  77500]))

# %%
pdf = pdf[pdf["hash"] == "0xrgf01465dagg7w"]

# %%
print(np.unique(pdf.prediction, return_counts = True))
print(np.unique(pdf.prediction_2, return_counts = True))
print(np.unique(pdf.prediction_3, return_counts = True))
print(np.unique(pdf.prediction_4, return_counts = True))
# Out:
# (array([1.]), array([122500]))
# (array([0., 1.]), array([38770, 83730]))
# (array([0., 1.]), array([38770, 83730]))
# (array([0., 1.]), array([38889, 83611]))

# %%
83730/122500*100 # EFDT
# Out:
# 68.35102040816327

# %%
83730/122500*100 # ARF
# Out:
# 68.35102040816327

# %%
83611/122500*100 # HT
# Out:
# 68.25387755102041

# %%
df = spark.read.format("csv").options(header='true').schema(input_schema). \
load("hdfs://cluster-9e14-m/user/hdfs/stream/sea")

# %%
pdf = df.toPandas()

# %%
pdf
# Out:
#               V1        V2        V3  Class
# 0       6.735018  0.027444  5.299264    0.0
# 1       5.375940  3.458857  4.995397    1.0
# 2       6.211646  8.847723  2.737267    1.0
# 3       2.832911  2.280511  9.310785    0.0
# 4       1.177168  7.039665  6.839691    1.0
# ...          ...       ...       ...    ...
# 199995  4.783841  2.285484  5.794637    0.0
# 199996  8.516639  0.994268  5.878430    1.0
# 199997  3.036674  2.191741  3.114785    0.0
# 199998  4.209259  2.071012  3.945232    0.0
# 199999  1.951555  2.840922  3.068156    0.0
#
# [200000 rows x 4 columns]

# %%
np.unique(pdf.Class, return_counts=True)
# Out:
# (array([0., 1.]), array([ 63548, 136452]))

# %%
136452/200000*100
# Out:
# 68.226

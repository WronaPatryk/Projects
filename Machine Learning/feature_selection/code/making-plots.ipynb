# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Digits

# %%
res_digits = pd.read_csv("results2-digits.csv", index_col=0)

# %%
res_digits
# Out:
#       lr  n_est  max_depth      m     score    case  standardize
# 0    0.1   30.0        5.0   50.0  0.919661   case1          0.0
# 1    0.1   30.0        5.0   50.0  0.920105   case1          1.0
# 2    0.1   40.0        5.0   50.0  0.930964   case1          0.0
# 3    0.1   40.0        5.0   50.0  0.930541   case1          1.0
# 4    0.1   50.0        5.0   50.0  0.932534   case1          0.0
# ..   ...    ...        ...    ...       ...     ...          ...
# 813  0.5   50.0        7.0  125.0  0.962540  case10          1.0
# 814  0.5   60.0        7.0  125.0  0.962242  case10          0.0
# 815  0.5   60.0        7.0  125.0  0.961578  case10          1.0
# 816  0.5   70.0        7.0  125.0  0.962353  case10          0.0
# 817  0.5   70.0        7.0  125.0  0.963292  case10          1.0
#
# [818 rows x 7 columns]

# %%
plot_df = pd.DataFrame(res_digits.groupby([ "m"])["score"].agg(np.mean)).reset_index()

ax = sns.lineplot(data=plot_df, x= "m", y = "score")
ax.set(xlabel='Number of features - m', ylabel='Average Score')
ax.set_title("Digits data - GradientBoosting results on validation dataset")
ax.set_label

plt.show()

# %%
plot_df = pd.DataFrame(res_digits.groupby(["lr", "m"])["score"].agg(np.mean)).reset_index()

ax = sns.lineplot(data=plot_df, hue="lr", x= "m", y = "score")
ax.set(xlabel='Number of features - m', ylabel='Average Score')
ax.set_title("Digits data - GradientBoosting results on validation dataset")
ax.set_label

plt.show()

# %%
plot_df = pd.DataFrame(res_digits.groupby(["max_depth", "m"])["score"].agg(np.mean)).reset_index()

ax = sns.lineplot(data=plot_df, hue="max_depth", x= "m", y = "score")
ax.set(xlabel='Number of features - m', ylabel='Average Score(m)')
ax.set_title("Digits data - GradientBoosting results on validation dataset")
plt.show()

# %%
plot_df = pd.DataFrame(res_digits.groupby(["n_est", "m"])["score"].agg(np.mean)).reset_index()

ax = sns.lineplot(data=plot_df, hue="n_est", x= "m", y = "score")
ax.set(xlabel='Number of features - m', ylabel='Average Score')
ax.set_title("Digits data - GradientBoosting results on validation dataset")

plt.show()

# %% [markdown]
# # Artificial

# %%
res_art = pd.read_csv("results5_2-artificial.csv", index_col=0)

# %%
res_art
# Out:
#         lr  n_est  max_depth     m     score    case  standardize
# 0     0.05   10.0        3.0   5.0  0.582403   case1          0.0
# 1     0.05   10.0        3.0   5.0  0.582403   case1          1.0
# 2     0.05   20.0        3.0   5.0  0.586783   case1          0.0
# 3     0.05   20.0        3.0   5.0  0.586395   case1          1.0
# 4     0.05   30.0        3.0   5.0  0.612150   case1          0.0
# ...    ...    ...        ...   ...       ...     ...          ...
# 3915  0.50   50.0        7.0  10.0  0.835883  case14          1.0
# 3916  0.50   60.0        7.0  10.0  0.846356  case14          0.0
# 3917  0.50   60.0        7.0  10.0  0.845081  case14          1.0
# 3918  0.50   70.0        7.0  10.0  0.844433  case14          0.0
# 3919  0.50   70.0        7.0  10.0  0.854238  case14          1.0
#
# [3920 rows x 7 columns]

# %%
plot_df = pd.DataFrame(res_art.groupby([ "m"])["score"].agg(np.mean)).reset_index()

ax = sns.lineplot(data=plot_df, x= "m", y = "score")
ax.set(xlabel='Number of features - m', ylabel='Average Score')
ax.set_title("Artificial data - GradientBoosting results on validation dataset")
ax.set_label

plt.show()

# %%
plot_df = pd.DataFrame(res_art.groupby(["lr", "m"])["score"].agg(np.mean)).reset_index()

ax = sns.lineplot(data=plot_df, hue="lr", x= "m", y = "score")
ax.set(xlabel='Number of features - m', ylabel='Average Score')
ax.set_title("Artificial data - GradientBoosting results on validation dataset")
ax.set_label

plt.show()

# %%
plot_df = pd.DataFrame(res_art.groupby(["max_depth", "m"])["score"].agg(np.mean)).reset_index()

ax = sns.lineplot(data=plot_df, hue="max_depth", x= "m", y = "score")
ax.set(xlabel='Number of features - m', ylabel='Average Score')
ax.set_title("Artificial data - GradientBoosting results on validation dataset")
plt.show()

# %%
plot_df = pd.DataFrame(res_art.groupby(["n_est", "m"])["score"].agg(np.mean)).reset_index()

ax = sns.lineplot(data=plot_df, hue="n_est", x= "m", y = "score")
ax.set(xlabel='Number of features - m', ylabel='Average Score')
ax.set_title("Artificial data - GradientBoosting results on validation dataset")

plt.show()
